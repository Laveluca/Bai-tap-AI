# %% [markdown]
# <a href="https://colab.research.google.com/github/Laveluca/Bai-tap-AI/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook
Wb = Workbook()
Sheet = Wb.active
Sheet['A1'] = ' Nguyen Quoc Trung'
Sheet['B1'] = ' 20104066 '
Sheet['A2'] = ' Quoc Bao '
Sheet['B2'] = ' 20104016 '
Sheet['A3'] = ' Minh Hung'
Sheet['B3'] = ' 20104000 '
Wb.save('text.xlsx')

# %%
import openpyxl
Wb = openpyxl.load_workbook('text.xlsx')
Sheet = Wb.active
t1 = Sheet['A1']
t2 = Sheet['B1']
t3 = Sheet.cell(row=2,column=1)
t4 = Sheet.cell(row=2,column=2)
t5 = Sheet.cell(row=3,column=1)
t6 = Sheet.cell(row=3,column=2)
print(t1.value,t2.value)
print(t3.value,t4.value)
print(t5.value,t6.value)
# Out:
#  Nguyen Quoc Trung  20104066
#  Quoc Bao   20104016
#  Minh Hung  20104000

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(6)
y= x+1
plt.plot(x,y,'o--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(6)
y= x+1
plt.plot(x,y,'o--')
plt.plot(x,-y,'o-')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(6)
y= x+1
plt.plot(x,y,'o--')
plt.plot(x,-y,'o-')
plt.title('y=x and y=-x ')
plt.xlabel('Trục x')
plt.ylabel('Trục y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
N=16
x=np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
N=16
x=np.linspace(0,15,16)
y=np.logspace(0.1,2,16)
plt.plot(x,y, '--o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(25)
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(25)
plt.plot(x,x**3+1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(7)
plt.plot(x,-x**2,'-')
plt.plot(x,-x**3,'--')
plt.plot(x,-2*x,'-.')
plt.plot(x,-2**x,':')
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2)
plt.plot(x,-x**3)
plt.plot(x,-2*x)
plt.plot(x,-2**x)
plt.grid(True)
plt.savefig('text.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(3)
plt.subplots_adjust(wspace=0.3,hspace=0.3)
plt.subplot(2,2,1) #số đầu tiên là hàng, số tiếp theo là cột và số cuối cùng là phần tử tác động.
plt.plot(x,-x**2, color='g')
plt.subplot(2,2,2)
plt.plot(x,-x**3, color='r')
plt.subplot(2,2,3)
plt.plot(x,-2*x,color='b')
plt.subplot(2,2,4)
plt.plot(x,-2**x,'o--')
plt.show()

# %%
plt.axis([0,100,0,10])
plt.scatter(60,7,s=1000, color='g',alpha=1)
plt.scatter(80,5,s=1000,color='r',alpha=0.5)
plt.scatter(40,3,s=1000,color='b',alpha=1)
plt.show()

# %%
plt.axis([0,10,0,10])
plt.plot([8,8],linewidth=5, color='r',alpha=1)
plt.text(5,5, " Oke bạn ơi ")
plt.show()
# đang bị lỗi

# %%
x = np.arange(4)
y=np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0],color='b', width= 0.25)
plt.bar(x+0.25,y[1],color='g', width= 0.25)
plt.bar(x+0.5,y[2],color='r', width= 0.25)
plt.show()

# %%
x = np.arange(4)
y=np.random.rand(4)
plt.barh(x,y)
plt.show()

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
size=20
plt.scatter(x,y,s=size,c=colors,alpha=1)
plt.show()

# %%
pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 2.1 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=739427d9dfe8888e13bfa9e12f29b6cd5e4cc6a66f5dd2a5015ed15837bcf3f9
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Consequent(np.arange(10,26,1),'tip')
food['poor']= fuzz.trimf(food.universe,[0,0,5])
food['average']= fuzz.trimf(food.universe,[0,5,10])
food['good']= fuzz.trimf(food.universe,[5,10,10])
service['poor']= fuzz.trimf(service.universe,[0,0,5])
service['average']= fuzz.trimf(service.universe,[0,5,10])
service['good']= fuzz.trimf(service.universe,[5,10,10])
tip['poor']= fuzz.trimf(tip.universe,[10,14,18])
tip['average']= fuzz.trimf(tip.universe,[14,18,22])
tip['good']= fuzz.trimf(tip.universe,[18,22,25])
service.view()
food.view()
tip.view()

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Consequent(np.arange(10,26,1),'tip')
food['poor']= fuzz.trimf(food.universe,[0,0,5])
food['average']= fuzz.trimf(food.universe,[0,5,10])
food['good']= fuzz.trimf(food.universe,[5,10,10])
service['poor']= fuzz.trimf(service.universe,[0,0,5])
service['average']= fuzz.trimf(service.universe,[0,5,10])
service['good']= fuzz.trimf(service.universe,[5,10,10])
tip['poor']= fuzz.trimf(tip.universe,[10,14,18])
tip['average']= fuzz.trimf(tip.universe,[14,18,22])
tip['good']= fuzz.trimf(tip.universe,[18,22,25])

service.view()
food.view()
tip.view()
rule1 = ctrl.Rule(food['poor']& service['poor'], tip['poor'])
rule2 = ctrl.Rule(food['poor']& service['average'], tip['poor'])
rule3 = ctrl.Rule(food['poor']& service['good'], tip['average'])
rule4 = ctrl.Rule(food['average']& service['poor'], tip['poor'])
rule5 = ctrl.Rule(food['average']& service['poor'], tip['average'])
rule6 = ctrl.Rule(food['average']& service['poor'], tip['average'])
rule7 = ctrl.Rule(food['good']& service['poor'], tip['average'])
rule8 = ctrl.Rule(food['good']& service['average'], tip['good'])
rule9 = ctrl.Rule(food['good']& service['good'], tip['good'])

tipping_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
tipping=ctrl.ControlSystemSimulation(tipping_ctrl)
tipping.input['food']=6.2
tipping.input['service']=3.5
tipping.compute()
print(tipping.output['tip'])
tip.view(sim=tipping)
# Out:
# 17.332916666666666
